# %% [markdown]
# <h1 align='center'>Python Regular Expression Tutorial Exericse</h1>

# %%
import re

# %% [markdown]
# **1. Extract all Python package names from the following text. The package name is the text that appears after the domain in URLs like https://pypi.org/project/, https://github.com/python/, or https://readthedocs.org/projects/. Package names contain only alphanumeric characters, hyphens and underscores.**

# %%
text = '''
Check out these useful Python packages for data science:
NumPy for numerical computing: https://pypi.org/project/numpy/
Pandas documentation: https://pandas.pydata.org/
Source code at https://github.com/pandas-dev/pandas
Also see https://pypi.org/project/scikit-learn/ and https://pypi.org/project/matplotlib/
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %%
# %load solutions/regex_ex1_package_names.py

# %% [markdown]
# **2. Extract Concentration Risk Types. It will be a text that appears after "Concentration Risk:", In below example, your regex should extract these two strings**
#
# (1) Credit Risk
#
# (2) Supply Rish

# %%
text = '''
Concentration of Risk: Credit Risk
Financial instruments that potentially subject us to a concentration of credit risk consist of cash, cash equivalents, marketable securities,
restricted cash, accounts receivable, convertible note hedges, and interest rate swaps. Our cash balances are primarily invested in money market funds
or on deposit at high credit quality financial institutions in the U.S. These deposits are typically in excess of insured limits. As of September 30, 2021
and December 31, 2020, no entity represented 10% or more of our total accounts receivable balance. The risk of concentration for our convertible note
hedges and interest rate swaps is mitigated by transacting with several highly-rated multinational banks.
Concentration of Risk: Supply Risk
We are dependent on our suppliers, including single source suppliers, and the inability of these suppliers to deliver necessary components of our
products in a timely manner at prices, quality levels and volumes acceptable to us, or our inability to efficiently manage these components from these
suppliers, could have a material adverse effect on our business, prospects, financial condition and operating results.
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %%
# %load solutions/regex_ex2_concentration_risk.py

# %% [markdown]
# **3. Companies in Europe report their financial numbers on a semi-annual basis and you can have a document like this. Extract the quarterly and semi-annual period references (e.g., FY2021 Q1, FY2021 S1).**
#
# Hint: you need to use (?:) here to match everything enclosed

# %%
text = '''
Toyota's gross cost of operating lease vehicles in FY2021 Q1 was $4.85 billion.
BMW's gross cost of operating vehicles in FY2021 S1 was $8 billion.
'''

pattern = '' # todo: type your regex here
matches = re.findall(pattern, text)
matches

# %%
# %load solutions/regex_ex3_fiscal_periods.py

# %% [markdown]
# **4. Extract all valid email addresses from the following text.**

# %%
text = '''
For general inquiries, contact support@example.com or sales_team@company.org.
You can also reach john.doe@university.edu for academic questions.
Invalid emails like user@ or @domain.com should not match.
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %%
# %load solutions/regex_ex4_emails.py

# %% [markdown]
# **5. Extract all dates from the following text. Dates can be in formats: YYYY-MM-DD, DD/MM/YYYY, or MM-DD-YYYY**

# %%
text = '''
Meeting scheduled for 2024-03-15 at 10am.
The project deadline is 15/03/2024.
Invoice dated: 03-15-2024.
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %%
# %load solutions/regex_ex5_dates.py

# %% [markdown]
# **6. Extract all phone numbers from the following text. Numbers may have different formats.**

# %%
text = '''
Contact us at +1-555-123-4567 or (555) 987-6543.
International: +44 20 7946 0958
Local: 555.321.9876
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %%
# %load solutions/regex_ex6_phones.py
